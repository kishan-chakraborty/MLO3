# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

from MLO.env import MABEnvironment
from MLO.utils import AP, NonAP, cal_kl_distance, cal_tv_distance, cal_log_ratio_distance

# %%
with open(f'data/seed{1}_exp3_experimental_environment_data.pkl', 'rb') as f:
    env = pickle.load(f)

# %%
aps = env.aps
non_aps = env.nonaps

# %%
for n_ap in non_aps:
    highest_prob_idx = np.argmax(n_ap.learner.probs)
    print(f'best arm {n_ap.available_arms[highest_prob_idx]}, probability: {n_ap.learner.probs[highest_prob_idx]}', )
# Out:
# best arm (1, 0), probability: 0.9249944097889428
# best arm (3, 0), probability: 0.924998696119195
# best arm (1, 0), probability: 0.9249921042517315
# best arm (3, 0), probability: 0.9249806240827878
# best arm (2, 0), probability: 0.9249997581685617
# best arm (2, 0), probability: 0.922683329026989
# best arm (3, 0), probability: 0.9249847154929146
# best arm (0, 0), probability: 0.9249768556742425
# best arm (0, 0), probability: 0.9235580006604338
# best arm (0, 0), probability: 0.924997011008982
# best arm (0, 0), probability: 0.9249632304894814
# best arm (3, 0), probability: 0.9249998249058847
# best arm (1, 0), probability: 0.9249584564718597
# best arm (0, 0), probability: 0.9246828970972414
# best arm (2, 0), probability: 0.9249999870477977
# best arm (3, 0), probability: 0.9248118008392859
# best arm (1, 0), probability: 0.9249893319015272
# best arm (1, 0), probability: 0.9249971979624859
# best arm (2, 0), probability: 0.9249944348851963
# best arm (2, 0), probability: 0.9249984451426595

# %%
non_ap_probs = non_aps[5].learner.save_probs

# %%
plt.plot(non_ap_probs)
# Out:
# [<matplotlib.lines.Line2D at 0x7e3f0075c7d0>,
#  <matplotlib.lines.Line2D at 0x7e3ee7299430>,
#  <matplotlib.lines.Line2D at 0x7e3ef59f92e0>,
#  <matplotlib.lines.Line2D at 0x7e3ee7299520>]

# %%
# Find the kl distance for prob corresponding to UE 0
kl_dist = cal_kl_distance(non_ap_probs[:-1], non_ap_probs[1:])
tv_dist = cal_tv_distance(non_ap_probs[:-1], non_ap_probs[1:])
log_ratio_dist = cal_log_ratio_distance(non_ap_probs[:-1], non_ap_probs[1:])

# %%
plt.plot(tv_dist)

# %%
plt.plot(kl_dist)

# %%
plt.plot(log_ratio_dist)
# Out:
# [<matplotlib.lines.Line2D at 0x7e3eebb1e7e0>,
#  <matplotlib.lines.Line2D at 0x7e3ef2c08320>,
#  <matplotlib.lines.Line2D at 0x7e3eebb1e7b0>,
#  <matplotlib.lines.Line2D at 0x7e3eebb1e960>]
