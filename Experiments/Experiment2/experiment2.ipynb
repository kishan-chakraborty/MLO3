# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

from MLO.env import MABEnvironment
from MLO.utils import AP, NonAP

# %%
with open(f'data/experiment2/seed{1}_exp3_environment_data.pkl', 'rb') as f:
    env = pickle.load(f)

# %%
aps = env.aps
non_aps = env.nonaps

# %%
for n_ap in non_aps:
    highest_prob_idx = np.argmax(n_ap.learner.probs)
    print(f'best arm {n_ap.available_arms[highest_prob_idx]}, probability: {n_ap.learner.probs[highest_prob_idx]}', )
# Out:
# best arm (0, 2), probability: 0.9333333333333308
# best arm (0, 2), probability: 0.9333333333333131
# best arm (0, 2), probability: 0.9333333333331341
# best arm (0, 2), probability: 0.9333333333333296
