# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

from MLO.env import Experiment
from MLO.utils import AP, NonAP, cal_kl_distance, cal_tv_distance, cal_log_ratio_distance

# %%
with open(f'data/seed1_exp3_environment_data.pkl', 'rb') as f:
    exp = pickle.load(f)

# %%
aps = exp.aps
non_aps = aps = exp.nonaps

# %%
for n_ap in non_aps:
    highest_prob_idx = np.argmax(n_ap.learner.probs)
    print(f'best arm {n_ap.available_actions[highest_prob_idx]}, probability: {n_ap.learner.probs[highest_prob_idx]}', )
# Out:
# best arm (1, 2), probability: 0.6268036813796708
# best arm (0, 2), probability: 0.9001602446515454
# best arm (3, 2), probability: 0.9074516039271137
# best arm (3, 2), probability: 0.811989383912098
# best arm (2, 2), probability: 0.7122972452673051
# best arm (1, 2), probability: 0.8906614239504415
# best arm (0, 2), probability: 0.8484354104307946
# best arm (2, 2), probability: 0.7423751265520959
# best arm (2, 2), probability: 0.9064887598725386
# best arm (1, 2), probability: 0.9052109919485454
# best arm (0, 2), probability: 0.9081829765267555
# best arm (1, 2), probability: 0.9070071738240721
# best arm (0, 2), probability: 0.908272992055369
# best arm (2, 2), probability: 0.8864725023817138
# best arm (2, 2), probability: 0.5743835450008279
# best arm (3, 2), probability: 0.9065751231485267
# best arm (3, 2), probability: 0.7058978669084519
# best arm (0, 2), probability: 0.404361171856676
# best arm (1, 2), probability: 0.9050554663180232
# ...
